# %%
from agents.mcp import MCPServerStdio

# %%
fetch_params = {"command": "uvx", "args": ["mcp-server-fetch"]}

async with MCPServerStdio(params=fetch_params, client_session_timeout_seconds=60) as server:
    fetch_tools = await server.list_tools()

fetch_tools
# Out:
# Error initializing MCP server: fileno
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# File c:\Users\edan\repos\personal_projects\AI\Agentic_AI_Projects\openai_sdk_resume_assistant\.venv\Lib\site-packages\mcp\os\win32\utilities.py:169, in create_windows_process(command, args, env, errlog, cwd)
#     167 try:
#     168     # First try using anyio with Windows-specific flags to hide console window
# --> 169     process = await anyio.open_process(
#     170         [command, *args],
#     171         env=env,
#     172         # Ensure we don't create console windows for each process
#     173         creationflags=subprocess.CREATE_NO_WINDOW  # type: ignore
#     174         if hasattr(subprocess, "CREATE_NO_WINDOW")
#     175         else 0,
#     176         stderr=errlog,
#     177         cwd=cwd,
#     178     )
#     179 except NotImplementedError:
#     180     # If Windows doesn't support async subprocess creation, use fallback
#
# File c:\Users\edan\repos\personal_projects\AI\Agentic_AI_Projects\openai_sdk_resume_assistant\.venv\Lib\site-packages\anyio\_core\_subprocesses.py:190, in open_process(command, stdin, stdout, stderr, cwd, env, startupinfo, creationflags, start_new_session, pass_fds, user, group, extra_groups, umask)
#     188     kwargs["umask"] = umask
# --> 190 return await get_async_backend().open_process(
#     191     command,
#     192     stdin=stdin,
#     193     stdout=stdout,
#     194     stderr=stderr,
#     195     cwd=cwd,
#     196     env=env,
#     197     startupinfo=startupinfo,
#     198     creationflags=creationflags,
#     199     start_new_session=start_new_session,
#     200     pass_fds=pass_fds,
#     201     **kwargs,
#     202 )
#
# File c:\Users\edan\repos\personal_projects\AI\Agentic_AI_Projects\openai_sdk_resume_assistant\.venv\Lib\site-packages\anyio\_backends\_asyncio.py:2561, in AsyncIOBackend.open_process(cls, command, stdin, stdout, stderr, **kwargs)
#    2560 else:
# -> 2561     process = await asyncio.create_subprocess_exec(
#    2562         *command,
#    2563         stdin=stdin,
#    2564         stdout=stdout,
#    2565         stderr=stderr,
#    2566         **kwargs,
#    2567     )
#    2569 stdin_stream = StreamWriterWrapper(process.stdin) if process.stdin else None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\subprocess.py:224, in create_subprocess_exec(program, stdin, stdout, stderr, limit, *args, **kwds)
#     222 protocol_factory = lambda: SubprocessStreamProtocol(limit=limit,
#     223                                                     loop=loop)
# --> 224 transport, protocol = await loop.subprocess_exec(
#     225     protocol_factory,
#     226     program, *args,
#     227     stdin=stdin, stdout=stdout,
#     228     stderr=stderr, **kwds)
#     229 return Process(transport, protocol, loop)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py:1743, in BaseEventLoop.subprocess_exec(self, protocol_factory, program, stdin, stdout, stderr, universal_newlines, shell, bufsize, encoding, errors, text, *args, **kwargs)
#    1742     self._log_subprocess(debug_log, stdin, stdout, stderr)
# -> 1743 transport = await self._make_subprocess_transport(
#    1744     protocol, popen_args, False, stdin, stdout, stderr,
#    1745     bufsize, **kwargs)
#    1746 if self._debug and debug_log is not None:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\windows_events.py:400, in ProactorEventLoop._make_subprocess_transport(self, protocol, args, shell, stdin, stdout, stderr, bufsize, extra, **kwargs)
#     399 waiter = self.create_future()
# --> 400 transp = _WindowsSubprocessTransport(self, protocol, args, shell,
#     401                                      stdin, stdout, stderr, bufsize,
#     402                                      waiter=waiter, extra=extra,
#     403                                      **kwargs)
#     404 try:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_subprocess.py:36, in BaseSubprocessTransport.__init__(self, loop, protocol, args, shell, stdin, stdout, stderr, bufsize, waiter, extra, **kwargs)
#      35 try:
# ---> 36     self._start(args=args, shell=shell, stdin=stdin, stdout=stdout,
#      37                 stderr=stderr, bufsize=bufsize, **kwargs)
#      38 except:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\windows_events.py:878, in _WindowsSubprocessTransport._start(self, args, shell, stdin, stdout, stderr, bufsize, **kwargs)
#     877 def _start(self, args, shell, stdin, stdout, stderr, bufsize, **kwargs):
# --> 878     self._proc = windows_utils.Popen(
#     879         args, shell=shell, stdin=stdin, stdout=stdout, stderr=stderr,
#     880         bufsize=bufsize, **kwargs)
#     882     def callback(f):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\windows_utils.py:153, in Popen.__init__(self, args, stdin, stdout, stderr, **kwds)
#     152 try:
# --> 153     super().__init__(args, stdin=stdin_rfd, stdout=stdout_wfd,
#     154                      stderr=stderr_wfd, **kwds)
#     155 except:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:992, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#     975 # Input and output objects. The general principle is like
#     976 # this:
#     977 #
#    (...)    987 # are -1 when not using PIPEs. The child objects are -1
#     988 # when not redirecting.
#     990 (p2cread, p2cwrite,
#     991  c2pread, c2pwrite,
# --> 992  errread, errwrite) = self._get_handles(stdin, stdout, stderr)
#     994 # From here on, raising exceptions may cause file descriptor leakage
#     995
#     996 # We wrap OS handles *before* launching the child, otherwise a
#     997 # quickly terminating child could make our fds unwrappable
#     998 # (see #8458).
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:1406, in Popen._get_handles(self, stdin, stdout, stderr)
#    1404 else:
#    1405     # Assuming file-like object
# -> 1406     errwrite = msvcrt.get_osfhandle(stderr.fileno())
#    1407 errwrite = self._make_inheritable(errwrite)
#
# File c:\Users\edan\repos\personal_projects\AI\Agentic_AI_Projects\openai_sdk_resume_assistant\.venv\Lib\site-packages\ipykernel\iostream.py:371, in OutStream.fileno(self)
#     370 msg = "fileno"
# --> 371 raise io.UnsupportedOperation(msg)
#
# UnsupportedOperation: fileno
#
# During handling of the above exception, another exception occurred:
#
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[5], line 3
#       1 fetch_params = {"command": "uvx", "args": ["mcp-server-fetch"]}
# ----> 3 async with MCPServerStdio(params=fetch_params, client_session_timeout_seconds=60) as server:
#       4     fetch_tools = await server.list_tools()
#       6 fetch_tools
#
# File c:\Users\edan\repos\personal_projects\AI\Agentic_AI_Projects\openai_sdk_resume_assistant\.venv\Lib\site-packages\agents\mcp\server.py:208, in _MCPServerWithClientSession.__aenter__(self)
#     207 async def __aenter__(self):
# --> 208     await self.connect()
#     209     return self
#
# File c:\Users\edan\repos\personal_projects\AI\Agentic_AI_Projects\openai_sdk_resume_assistant\.venv\Lib\site-packages\agents\mcp\server.py:221, in _MCPServerWithClientSession.connect(self)
#     219 """Connect to the server."""
#     220 try:
# --> 221     transport = await self.exit_stack.enter_async_context(self.create_streams())
#     222     # streamablehttp_client returns (read, write, get_session_id)
#     223     # sse_client returns (read, write)
#     225     read, write, *_ = transport
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:659, in AsyncExitStack.enter_async_context(self, cm)
#     655 except AttributeError:
#     656     raise TypeError(f"'{cls.__module__}.{cls.__qualname__}' object does "
#     657                     f"not support the asynchronous context manager protocol"
#     658                    ) from None
# --> 659 result = await _enter(cm)
#     660 self._push_async_cm_exit(cm, _exit)
#     661 return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:210, in _AsyncGeneratorContextManager.__aenter__(self)
#     208 del self.args, self.kwds, self.func
#     209 try:
# --> 210     return await anext(self.gen)
#     211 except StopAsyncIteration:
#     212     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\edan\repos\personal_projects\AI\Agentic_AI_Projects\openai_sdk_resume_assistant\.venv\Lib\site-packages\mcp\client\stdio\__init__.py:123, in stdio_client(server, errlog)
#     120     command = _get_executable_command(server.command)
#     122     # Open process with stderr piped for capture
# --> 123     process = await _create_platform_compatible_process(
#     124         command=command,
#     125         args=server.args,
#     126         env=({**get_default_environment(), **server.env} if server.env is not None else get_default_environment()),
#     127         errlog=errlog,
#     128         cwd=server.cwd,
#     129     )
#     130 except OSError:
#     131     # Clean up streams if process creation fails
#     132     await read_stream.aclose()
#
# File c:\Users\edan\repos\personal_projects\AI\Agentic_AI_Projects\openai_sdk_resume_assistant\.venv\Lib\site-packages\mcp\client\stdio\__init__.py:247, in _create_platform_compatible_process(command, args, env, errlog, cwd)
#     240 """
#     241 Creates a subprocess in a platform-compatible way.
#     242
#     243 Unix: Creates process in a new session/process group for killpg support
#     244 Windows: Creates process in a Job Object for reliable child termination
#     245 """
#     246 if sys.platform == "win32":
# --> 247     process = await create_windows_process(command, args, env, errlog, cwd)
#     248 else:
#     249     process = await anyio.open_process(
#     250         [command, *args],
#     251         env=env,
#    (...)    254         start_new_session=True,
#     255     )
#
# File c:\Users\edan\repos\personal_projects\AI\Agentic_AI_Projects\openai_sdk_resume_assistant\.venv\Lib\site-packages\mcp\os\win32\utilities.py:184, in create_windows_process(command, args, env, errlog, cwd)
#     181     process = await _create_windows_fallback_process(command, args, env, errlog, cwd)
#     182 except Exception:
#     183     # Try again without creation flags
# --> 184     process = await anyio.open_process(
#     185         [command, *args],
#     186         env=env,
#     187         stderr=errlog,
#     188         cwd=cwd,
#     189     )
#     191 _maybe_assign_process_to_job(process, job)
#     192 return process
#
# File c:\Users\edan\repos\personal_projects\AI\Agentic_AI_Projects\openai_sdk_resume_assistant\.venv\Lib\site-packages\anyio\_core\_subprocesses.py:190, in open_process(command, stdin, stdout, stderr, cwd, env, startupinfo, creationflags, start_new_session, pass_fds, user, group, extra_groups, umask)
#     187 if umask >= 0:
#     188     kwargs["umask"] = umask
# --> 190 return await get_async_backend().open_process(
#     191     command,
#     192     stdin=stdin,
#     193     stdout=stdout,
#     194     stderr=stderr,
#     195     cwd=cwd,
#     196     env=env,
#     197     startupinfo=startupinfo,
#     198     creationflags=creationflags,
#     199     start_new_session=start_new_session,
#     200     pass_fds=pass_fds,
#     201     **kwargs,
#     202 )
#
# File c:\Users\edan\repos\personal_projects\AI\Agentic_AI_Projects\openai_sdk_resume_assistant\.venv\Lib\site-packages\anyio\_backends\_asyncio.py:2561, in AsyncIOBackend.open_process(cls, command, stdin, stdout, stderr, **kwargs)
#    2553     process = await asyncio.create_subprocess_shell(
#    2554         command,
#    2555         stdin=stdin,
#    (...)   2558         **kwargs,
#    2559     )
#    2560 else:
# -> 2561     process = await asyncio.create_subprocess_exec(
#    2562         *command,
#    2563         stdin=stdin,
#    2564         stdout=stdout,
#    2565         stderr=stderr,
#    2566         **kwargs,
#    2567     )
#    2569 stdin_stream = StreamWriterWrapper(process.stdin) if process.stdin else None
#    2570 stdout_stream = StreamReaderWrapper(process.stdout) if process.stdout else None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\subprocess.py:224, in create_subprocess_exec(program, stdin, stdout, stderr, limit, *args, **kwds)
#     221 loop = events.get_running_loop()
#     222 protocol_factory = lambda: SubprocessStreamProtocol(limit=limit,
#     223                                                     loop=loop)
# --> 224 transport, protocol = await loop.subprocess_exec(
#     225     protocol_factory,
#     226     program, *args,
#     227     stdin=stdin, stdout=stdout,
#     228     stderr=stderr, **kwds)
#     229 return Process(transport, protocol, loop)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py:1743, in BaseEventLoop.subprocess_exec(self, protocol_factory, program, stdin, stdout, stderr, universal_newlines, shell, bufsize, encoding, errors, text, *args, **kwargs)
#    1741     debug_log = f'execute program {program!r}'
#    1742     self._log_subprocess(debug_log, stdin, stdout, stderr)
# -> 1743 transport = await self._make_subprocess_transport(
#    1744     protocol, popen_args, False, stdin, stdout, stderr,
#    1745     bufsize, **kwargs)
#    1746 if self._debug and debug_log is not None:
#    1747     logger.info('%s: %r', debug_log, transport)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\windows_events.py:400, in ProactorEventLoop._make_subprocess_transport(self, protocol, args, shell, stdin, stdout, stderr, bufsize, extra, **kwargs)
#     396 async def _make_subprocess_transport(self, protocol, args, shell,
#     397                                      stdin, stdout, stderr, bufsize,
#     398                                      extra=None, **kwargs):
#     399     waiter = self.create_future()
# --> 400     transp = _WindowsSubprocessTransport(self, protocol, args, shell,
#     401                                          stdin, stdout, stderr, bufsize,
#     402                                          waiter=waiter, extra=extra,
#     403                                          **kwargs)
#     404     try:
#     405         await waiter
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_subprocess.py:36, in BaseSubprocessTransport.__init__(self, loop, protocol, args, shell, stdin, stdout, stderr, bufsize, waiter, extra, **kwargs)
#      34 # Create the child process: set the _proc attribute
#      35 try:
# ---> 36     self._start(args=args, shell=shell, stdin=stdin, stdout=stdout,
#      37                 stderr=stderr, bufsize=bufsize, **kwargs)
#      38 except:
#      39     self.close()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\windows_events.py:878, in _WindowsSubprocessTransport._start(self, args, shell, stdin, stdout, stderr, bufsize, **kwargs)
#     877 def _start(self, args, shell, stdin, stdout, stderr, bufsize, **kwargs):
# --> 878     self._proc = windows_utils.Popen(
#     879         args, shell=shell, stdin=stdin, stdout=stdout, stderr=stderr,
#     880         bufsize=bufsize, **kwargs)
#     882     def callback(f):
#     883         returncode = self._proc.poll()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\windows_utils.py:153, in Popen.__init__(self, args, stdin, stdout, stderr, **kwds)
#     151     stderr_wfd = stderr
#     152 try:
# --> 153     super().__init__(args, stdin=stdin_rfd, stdout=stdout_wfd,
#     154                      stderr=stderr_wfd, **kwds)
#     155 except:
#     156     for h in (stdin_wh, stdout_rh, stderr_rh):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:992, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#     973         raise ValueError(f"User ID cannot be negative, got {uid}")
#     975 # Input and output objects. The general principle is like
#     976 # this:
#     977 #
#    (...)    987 # are -1 when not using PIPEs. The child objects are -1
#     988 # when not redirecting.
#     990 (p2cread, p2cwrite,
#     991  c2pread, c2pwrite,
# --> 992  errread, errwrite) = self._get_handles(stdin, stdout, stderr)
#     994 # From here on, raising exceptions may cause file descriptor leakage
#     995
#     996 # We wrap OS handles *before* launching the child, otherwise a
#     997 # quickly terminating child could make our fds unwrappable
#     998 # (see #8458).
#    1000 if _mswindows:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:1406, in Popen._get_handles(self, stdin, stdout, stderr)
#    1403         errwrite = msvcrt.get_osfhandle(stderr)
#    1404     else:
#    1405         # Assuming file-like object
# -> 1406         errwrite = msvcrt.get_osfhandle(stderr.fileno())
#    1407     errwrite = self._make_inheritable(errwrite)
#    1409 return (p2cread, p2cwrite,
#    1410         c2pread, c2pwrite,
#    1411         errread, errwrite)
#
# File c:\Users\edan\repos\personal_projects\AI\Agentic_AI_Projects\openai_sdk_resume_assistant\.venv\Lib\site-packages\ipykernel\iostream.py:371, in OutStream.fileno(self)
#     369     return self._original_stdstream_copy
#     370 msg = "fileno"
# --> 371 raise io.UnsupportedOperation(msg)
#
# UnsupportedOperation: fileno

# %%
from agent_tools import send_email

# %%
send_email(body="This is an email test", subject="My Test email")
# Out:
# Email response 202
# {'status': 'success'}
